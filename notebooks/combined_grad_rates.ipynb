# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mnps_rates = pd.read_excel(r'C:\DA12\capstone\capstone-da12\data\graduation rates\MNPS.xlsx')
mnps_rates
# Out:
#    ID  year  number_of_schools  admin  teachers  total students  \
# 0   0  2010                133    562      5064           75100
# 1   1  2011                137    557      5216           81003
# 2   2  2012                143    592      5127           78975
# 3   3  2013                158    757      5576           81134
# 4   4  2014                156    603      5394           82806
# 5   5  2015                154    601      5314           84070
# 6   6  2016                164    727      5171           85123
# 7   7  2017                163    849      5082           85453
# 8   8  2018                159    334      5050           82424
# 9   9  2019                160    344      6046           81407
#
#    k_8_attendance  9_12_attendance  library_budget  social_budget  \
# 0            95.2             91.8     18445049.38     6004962.81
# 1            95.2             91.3     19769676.89     6236577.65
# ...

# %%
grad_rate_23 = pd.read_excel(r'C:\DA12\capstone\capstone-da12\data\graduation rates\2022-23_school_grad_rate_suppressed.xlsx')
grad_rate_23
# Out:
#       year  system                                 system_name  school  \
# 0     2023      10                             Anderson County       2
# 1     2023      10                             Anderson County       2
# 2     2023      10                             Anderson County       2
# 3     2023      10                             Anderson County       2
# 4     2023      10                             Anderson County       2
# ...    ...     ...                                         ...     ...
# 7870  2023     987  Tennessee Public Charter School Commission    8005
# 7871  2023     987  Tennessee Public Charter School Commission    8005
# 7872  2023     987  Tennessee Public Charter School Commission    8005
# 7873  2023     987  Tennessee Public Charter School Commission    8005
# 7874  2023     987  Tennessee Public Charter School Commission    8005
#
#                       school_name                     student_group  \
# ...

# %%
grad_rate_23 = grad_rate_23[grad_rate_23['system_name']=='Davidson County']
grad_rate_23
# Out:
#       year  system      system_name  school          school_name  \
# 994   2023     190  Davidson County       3  MNPS Virtual School
# 995   2023     190  Davidson County       3  MNPS Virtual School
# 996   2023     190  Davidson County       3  MNPS Virtual School
# 997   2023     190  Davidson County       3  MNPS Virtual School
# 998   2023     190  Davidson County       3  MNPS Virtual School
# ...    ...     ...              ...     ...                  ...
# 1616  2023     190  Davidson County    8110   KA @ The Crossings
# 1617  2023     190  Davidson County    8110   KA @ The Crossings
# 1618  2023     190  Davidson County    8110   KA @ The Crossings
# 1619  2023     190  Davidson County    8110   KA @ The Crossings
# 1620  2023     190  Davidson County    8110   KA @ The Crossings
#
#                        student_group  grad_cohort grad_count_state  \
# 994                     All Students           43               **
# ...

# %%
rates23 = grad_rate_23[grad_rate_23['student_group']=='All Students']
rates23
# Out:
#       year  system      system_name  school  \
# 994   2023     190  Davidson County       3
# 1011  2023     190  Davidson County      20
# 1032  2023     190  Davidson County      53
# 1047  2023     190  Davidson County      77
# 1067  2023     190  Davidson County     203
# 1083  2023     190  Davidson County     245
# 1103  2023     190  Davidson County     302
# 1119  2023     190  Davidson County     335
# 1139  2023     190  Davidson County     340
# 1159  2023     190  Davidson County     355
# 1177  2023     190  Davidson County     358
# 1198  2023     190  Davidson County     395
# 1218  2023     190  Davidson County     437
# 1238  2023     190  Davidson County     443
# 1254  2023     190  Davidson County     445
# 1273  2023     190  Davidson County     456
# 1290  2023     190  Davidson County     470
# 1311  2023     190  Davidson County     512
# 1329  2023     190  Davidson County     555
# 1349  2023     190  Davidson County     612
# ...

# %%
rates23.rename(columns={'grad_rate_state': 'grad_rate'}, inplace=True)
rates23
# Out:
# C:\Users\erica\AppData\Local\Temp\ipykernel_9376\3805586978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rates23.rename(columns={'grad_rate_state': 'grad_rate'}, inplace=True)
#       year  system      system_name  school  \
# 994   2023     190  Davidson County       3
# 1011  2023     190  Davidson County      20
# 1032  2023     190  Davidson County      53
# 1047  2023     190  Davidson County      77
# 1067  2023     190  Davidson County     203
# 1083  2023     190  Davidson County     245
# 1103  2023     190  Davidson County     302
# 1119  2023     190  Davidson County     335
# 1139  2023     190  Davidson County     340
# 1159  2023     190  Davidson County     355
# 1177  2023     190  Davidson County     358
# 1198  2023     190  Davidson County     395
# ...

# %%
grad_rate_21_22 = pd.read_excel(r'C:\DA12\capstone\capstone-da12\data\graduation rates\2021-22_school_grad_rate_suppressed.xlsx')
grad_rate_21_22
# Out:
#       year  system                                 system_name  school  \
# 0     2022      10                             Anderson County       2
# 1     2022      10                             Anderson County       2
# 2     2022      10                             Anderson County       2
# 3     2022      10                             Anderson County       2
# 4     2022      10                             Anderson County       2
# ...    ...     ...                                         ...     ...
# 7342  2022     987  Tennessee Public Charter School Commission    8005
# 7343  2022     987  Tennessee Public Charter School Commission    8005
# 7344  2022     987  Tennessee Public Charter School Commission    8005
# 7345  2022     987  Tennessee Public Charter School Commission    8005
# 7346  2022     987  Tennessee Public Charter School Commission    8005
#
#                       school_name                          student_group  \
# ...

# %%
grad_rate_22 = grad_rate_21_22[grad_rate_21_22['system_name']=='Davidson County']
grad_rate_22
# Out:
#       year  system      system_name  school           school_name  \
# 939   2022     190  Davidson County       3   MNPS Virtual School
# 940   2022     190  Davidson County       3   MNPS Virtual School
# 941   2022     190  Davidson County       3   MNPS Virtual School
# 942   2022     190  Davidson County       3   MNPS Virtual School
# 943   2022     190  Davidson County       3   MNPS Virtual School
# ...    ...     ...              ...     ...                   ...
# 1510  2022     190  Davidson County    8100  RePublic High School
# 1511  2022     190  Davidson County    8100  RePublic High School
# 1512  2022     190  Davidson County    8100  RePublic High School
# 1513  2022     190  Davidson County    8100  RePublic High School
# 1514  2022     190  Davidson County    8100  RePublic High School
#
#                        student_group  grad_cohort grad_count grad_rate
# 939                     All Students           47         46      97.9
# ...

# %%
rates22 = grad_rate_22[grad_rate_22['student_group']=='All Students']
rates22
# Out:
#       year  system      system_name  school  \
# 939   2022     190  Davidson County       3
# 957   2022     190  Davidson County      20
# 975   2022     190  Davidson County      53
# 991   2022     190  Davidson County      77
# 1011  2022     190  Davidson County     203
# 1028  2022     190  Davidson County     245
# 1046  2022     190  Davidson County     302
# 1059  2022     190  Davidson County     335
# 1077  2022     190  Davidson County     340
# 1095  2022     190  Davidson County     355
# 1112  2022     190  Davidson County     358
# 1132  2022     190  Davidson County     395
# 1150  2022     190  Davidson County     437
# 1168  2022     190  Davidson County     443
# 1181  2022     190  Davidson County     445
# 1200  2022     190  Davidson County     456
# 1219  2022     190  Davidson County     470
# 1238  2022     190  Davidson County     512
# 1256  2022     190  Davidson County     555
# 1271  2022     190  Davidson County     612
# ...

# %%
grad_rate_20_21 = pd.read_csv(r'C:\DA12\capstone\capstone-da12\data\graduation rates\school_grad_rate_suppressed.csv')
grad_rate_20_21
# Out:
#       year  system                         system_name  school  \
# 0     2021      10                     Anderson County       2
# 1     2021      10                     Anderson County       2
# 2     2021      10                     Anderson County       2
# 3     2021      10                     Anderson County       2
# 4     2021      10                     Anderson County       2
# ...    ...     ...                                 ...     ...
# 7098  2021     986  Tennessee State Board of Education    8005
# 7099  2021     986  Tennessee State Board of Education    8005
# 7100  2021     986  Tennessee State Board of Education    8005
# 7101  2021     986  Tennessee State Board of Education    8005
# 7102  2021     986  Tennessee State Board of Education    8005
#
#                       school_name                               subgroup  \
# 0     Anderson County High School                           All Students
# ...

# %%
grad_rate_21 = grad_rate_20_21[grad_rate_20_21['system_name']=='Davidson County']
grad_rate_21
# Out:
#       year  system      system_name  school           school_name  \
# 899   2021     190  Davidson County       3   MNPS Virtual School
# 900   2021     190  Davidson County       3   MNPS Virtual School
# 901   2021     190  Davidson County       3   MNPS Virtual School
# 902   2021     190  Davidson County       3   MNPS Virtual School
# 903   2021     190  Davidson County       3   MNPS Virtual School
# ...    ...     ...              ...     ...                   ...
# 1477  2021     190  Davidson County    8100  RePublic High School
# 1478  2021     190  Davidson County    8100  RePublic High School
# 1479  2021     190  Davidson County    8100  RePublic High School
# 1480  2021     190  Davidson County    8100  RePublic High School
# 1481  2021     190  Davidson County    8100  RePublic High School
#
#                               subgroup  grad_cohort grad_count grad_rate
# 899                       All Students           26         25      96.2
# ...

# %%
rates21 = grad_rate_21[grad_rate_21['subgroup']=='All Students']
rates21
# Out:
#       year  system      system_name  school  \
# 899   2021     190  Davidson County       3
# 914   2021     190  Davidson County      20
# 934   2021     190  Davidson County      53
# 950   2021     190  Davidson County      77
# 971   2021     190  Davidson County     203
# 989   2021     190  Davidson County     245
# 1008  2021     190  Davidson County     302
# 1024  2021     190  Davidson County     335
# 1043  2021     190  Davidson County     340
# 1063  2021     190  Davidson County     355
# 1081  2021     190  Davidson County     358
# 1099  2021     190  Davidson County     395
# 1120  2021     190  Davidson County     437
# 1131  2021     190  Davidson County     443
# 1145  2021     190  Davidson County     445
# 1163  2021     190  Davidson County     456
# 1180  2021     190  Davidson County     470
# 1200  2021     190  Davidson County     512
# 1218  2021     190  Davidson County     555
# 1235  2021     190  Davidson County     612
# ...

# %%
grad_rate_19_20 = pd.read_csv(r'C:\DA12\capstone\capstone-da12\data\graduation rates\2019-20_school_grad_rate_suppressed.csv')
grad_rate_19_20
# Out:
#       year  system                         system_name  school  \
# 0     2020      10                     Anderson County       2
# 1     2020      10                     Anderson County       2
# 2     2020      10                     Anderson County       2
# 3     2020      10                     Anderson County       2
# 4     2020      10                     Anderson County       2
# ...    ...     ...                                 ...     ...
# 7322  2020     986  Tennessee State Board of Education    8005
# 7323  2020     986  Tennessee State Board of Education    8005
# 7324  2020     986  Tennessee State Board of Education    8005
# 7325  2020     986  Tennessee State Board of Education    8005
# 7326  2020     986  Tennessee State Board of Education    8005
#
#                       school_name                               subgroup  \
# 0     Anderson County High School                           All Students
# ...

# %%
grad_rate_20 = grad_rate_19_20[grad_rate_19_20['system_name']=='Davidson County']
grad_rate_20
# Out:
#       year  system      system_name  school           school_name  \
# 928   2020     190  Davidson County       3   MNPS Virtual School
# 929   2020     190  Davidson County       3   MNPS Virtual School
# 930   2020     190  Davidson County       3   MNPS Virtual School
# 931   2020     190  Davidson County       3   MNPS Virtual School
# 932   2020     190  Davidson County       3   MNPS Virtual School
# ...    ...     ...              ...     ...                   ...
# 1499  2020     190  Davidson County    8100  RePublic High School
# 1500  2020     190  Davidson County    8100  RePublic High School
# 1501  2020     190  Davidson County    8100  RePublic High School
# 1502  2020     190  Davidson County    8100  RePublic High School
# 1503  2020     190  Davidson County    8100  RePublic High School
#
#                             subgroup  grad_cohort grad_count grad_rate
# 928                     All Students           20         17        85
# ...

# %%
rates20 = grad_rate_20[grad_rate_20['subgroup']=='All Students']
rates20
# Out:
#       year  system      system_name  school  \
# 928   2020     190  Davidson County       3
# 944   2020     190  Davidson County      20
# 963   2020     190  Davidson County      53
# 981   2020     190  Davidson County      77
# 1000  2020     190  Davidson County     165
# 1009  2020     190  Davidson County     203
# 1027  2020     190  Davidson County     245
# 1046  2020     190  Davidson County     302
# 1063  2020     190  Davidson County     335
# 1082  2020     190  Davidson County     340
# 1102  2020     190  Davidson County     355
# 1119  2020     190  Davidson County     358
# 1138  2020     190  Davidson County     395
# 1159  2020     190  Davidson County     437
# 1177  2020     190  Davidson County     443
# 1194  2020     190  Davidson County     445
# 1212  2020     190  Davidson County     456
# 1230  2020     190  Davidson County     470
# 1250  2020     190  Davidson County     512
# 1268  2020     190  Davidson County     555
# ...

# %%
grad_rate_18_19 = pd.read_csv(r'C:\DA12\capstone\capstone-da12\data\graduation rates\2018-19_school_grad_rate_suppressed.csv')
grad_rate_18_19
# Out:
#       year  system                  system_name  school  \
# 0     2019      10              Anderson County       2
# 1     2019      10              Anderson County       2
# 2     2019      10              Anderson County       2
# 3     2019      10              Anderson County       2
# 4     2019      10              Anderson County       2
# ...    ...     ...                          ...     ...
# 7131  2019     985  Achievement School District    8140
# 7132  2019     985  Achievement School District    8140
# 7133  2019     985  Achievement School District    8140
# 7134  2019     985  Achievement School District    8140
# 7135  2019     985  Achievement School District    8140
#
#                       school_name                        subgroup  \
# 0     Anderson County High School                    All Students
# 1     Anderson County High School                           Asian
# 2     Anderson County High School       Black or African American
# ...

# %%
grad_rate_19 = grad_rate_18_19[grad_rate_18_19['system_name']=='Davidson County']
grad_rate_19
# Out:
#       year  system      system_name  school           school_name  \
# 933   2019     190  Davidson County       3   MNPS Virtual School
# 934   2019     190  Davidson County       3   MNPS Virtual School
# 935   2019     190  Davidson County       3   MNPS Virtual School
# 936   2019     190  Davidson County       3   MNPS Virtual School
# 937   2019     190  Davidson County       3   MNPS Virtual School
# ...    ...     ...              ...     ...                   ...
# 1502  2019     190  Davidson County    8100  RePublic High School
# 1503  2019     190  Davidson County    8100  RePublic High School
# 1504  2019     190  Davidson County    8100  RePublic High School
# 1505  2019     190  Davidson County    8100  RePublic High School
# 1506  2019     190  Davidson County    8100  RePublic High School
#
#                             subgroup  grad_cohort grad_count grad_rate
# 933                     All Students           18         14      77.8
# ...

# %%
rates19 = grad_rate_19[grad_rate_18_19['subgroup']=='All Students']
rates19
# Out:
# C:\Users\erica\AppData\Local\Temp\ipykernel_9376\3168285153.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   rates19 = grad_rate_19[grad_rate_18_19['subgroup']=='All Students']
#       year  system      system_name  school  \
# 933   2019     190  Davidson County       3
# 949   2019     190  Davidson County      20
# 969   2019     190  Davidson County      53
# 986   2019     190  Davidson County      77
# 1005  2019     190  Davidson County     203
# 1021  2019     190  Davidson County     245
# 1041  2019     190  Davidson County     302
# 1057  2019     190  Davidson County     335
# 1075  2019     190  Davidson County     340
# 1094  2019     190  Davidson County     355
# 1114  2019     190  Davidson County     358
# 1135  2019     190  Davidson County     395
# 1155  2019     190  Davidson County     437
# 1172  2019     190  Davidson County     443
# 1188  2019     190  Davidson County     445
# ...

# %%
all = [rates19, rates20, rates21, rates22, rates23]
all
# Out:
# [      year  system      system_name  school  \
#  933   2019     190  Davidson County       3
#  949   2019     190  Davidson County      20
#  969   2019     190  Davidson County      53
#  986   2019     190  Davidson County      77
#  1005  2019     190  Davidson County     203
#  1021  2019     190  Davidson County     245
#  1041  2019     190  Davidson County     302
#  1057  2019     190  Davidson County     335
#  1075  2019     190  Davidson County     340
#  1094  2019     190  Davidson County     355
#  1114  2019     190  Davidson County     358
#  1135  2019     190  Davidson County     395
#  1155  2019     190  Davidson County     437
#  1172  2019     190  Davidson County     443
#  1188  2019     190  Davidson County     445
#  1205  2019     190  Davidson County     456
#  1225  2019     190  Davidson County     470
#  1245  2019     190  Davidson County     512
#  1263  2019     190  Davidson County     555
#  1281  2019     190  Davidson County     612
# ...

# %%
together = pd.concat(all)

# %%
together
# Out:
#       year  system      system_name  school  \
# 933   2019     190  Davidson County       3
# 949   2019     190  Davidson County      20
# 969   2019     190  Davidson County      53
# 986   2019     190  Davidson County      77
# 1005  2019     190  Davidson County     203
# ...    ...     ...              ...     ...
# 1522  2023     190  Davidson County    8045
# 1539  2023     190  Davidson County    8048
# 1567  2023     190  Davidson County    8075
# 1586  2023     190  Davidson County    8100
# 1603  2023     190  Davidson County    8110
#
#                                       school_name      subgroup  grad_cohort  \
# 933                           MNPS Virtual School  All Students           18
# 949                           Antioch High School  All Students          497
# 969             Nashville Big Picture High School  All Students           26
# 986                        Cane Ridge High School  All Students          427
# ...

# %%
rates = together[['year','school_name', 'grad_rate']]
rates
# Out:
#       year                                  school_name grad_rate
# 933   2019                          MNPS Virtual School      77.8
# 949   2019                          Antioch High School      72.8
# 969   2019            Nashville Big Picture High School        **
# 986   2019                       Cane Ridge High School      84.5
# 1005  2019            East Nashville Magnet High School        **
# ...    ...                                          ...       ...
# 1522  2023                       Valor Flagship Academy      98.5
# 1539  2023  Intrepid College Preparatory Charter School      95.9
# 1567  2023                        STEM Prep High School      97.6
# 1586  2023                         RePublic High School      92.5
# 1603  2023                           KA @ The Crossings        **
#
# [165 rows x 3 columns]

# %%
rates = rates.drop(rates[rates['grad_rate'] == '*'].index)
rates
# Out:
#       year                                  school_name grad_rate
# 933   2019                          MNPS Virtual School      77.8
# 949   2019                          Antioch High School      72.8
# 969   2019            Nashville Big Picture High School        **
# 986   2019                       Cane Ridge High School      84.5
# 1005  2019            East Nashville Magnet High School        **
# ...    ...                                          ...       ...
# 1522  2023                       Valor Flagship Academy      98.5
# 1539  2023  Intrepid College Preparatory Charter School      95.9
# 1567  2023                        STEM Prep High School      97.6
# 1586  2023                         RePublic High School      92.5
# 1603  2023                           KA @ The Crossings        **
#
# [150 rows x 3 columns]

# %%
rates = rates.drop(rates[rates['grad_rate'] == '**'].index)
rates
# Out:
#       year                                  school_name grad_rate
# 933   2019                          MNPS Virtual School      77.8
# 949   2019                          Antioch High School      72.8
# 986   2019                       Cane Ridge High School      84.5
# 1021  2019                        Glencliff High School      74.7
# 1057  2019                               Hillsboro High      92.1
# ...    ...                                          ...       ...
# 1505  2023                               LEAD Southeast      93.9
# 1522  2023                       Valor Flagship Academy      98.5
# 1539  2023  Intrepid College Preparatory Charter School      95.9
# 1567  2023                        STEM Prep High School      97.6
# 1586  2023                         RePublic High School      92.5
#
# [118 rows x 3 columns]

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118 entries, 933 to 1586
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         118 non-null    int64
#  1   school_name  118 non-null    object
#  2   grad_rate    118 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 3.7+ KB

# %%
rates['grad_rate'] =rates['grad_rate'].astype(float)
rates
# Out:
#       year                                  school_name  grad_rate
# 933   2019                          MNPS Virtual School       77.8
# 949   2019                          Antioch High School       72.8
# 986   2019                       Cane Ridge High School       84.5
# 1021  2019                        Glencliff High School       74.7
# 1057  2019                               Hillsboro High       92.1
# ...    ...                                          ...        ...
# 1505  2023                               LEAD Southeast       93.9
# 1522  2023                       Valor Flagship Academy       98.5
# 1539  2023  Intrepid College Preparatory Charter School       95.9
# 1567  2023                        STEM Prep High School       97.6
# 1586  2023                         RePublic High School       92.5
#
# [118 rows x 3 columns]

# %%
rates = rates.reset_index()
rates
# Out:
#      index  year                                  school_name  grad_rate
# 0      933  2019                          MNPS Virtual School       77.8
# 1      949  2019                          Antioch High School       72.8
# 2      986  2019                       Cane Ridge High School       84.5
# 3     1021  2019                        Glencliff High School       74.7
# 4     1057  2019                               Hillsboro High       92.1
# ..     ...   ...                                          ...        ...
# 113   1505  2023                               LEAD Southeast       93.9
# 114   1522  2023                       Valor Flagship Academy       98.5
# 115   1539  2023  Intrepid College Preparatory Charter School       95.9
# 116   1567  2023                        STEM Prep High School       97.6
# 117   1586  2023                         RePublic High School       92.5
#
# [118 rows x 4 columns]

# %%
rates.hist()
# Out:
# array([[<Axes: title={'center': 'index'}>,
#         <Axes: title={'center': 'year'}>],
#        [<Axes: title={'center': 'grad_rate'}>, <Axes: >]], dtype=object)

# %%
sns.histplot(data=rates, x="grad_rate")
plt.show()
# Out:
# C:\Users\erica\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.plot('grad_rate', 'year', data=rates, linestyle='-', marker='o')
plt.show()

# %%
top10 = rates.sort_values('grad_rate', ascending=False).head(10)
top10
# Out:
#      index  year                            school_name  grad_rate
# 114   1522  2023                 Valor Flagship Academy       98.5
# 96    1067  2023      East Nashville Magnet High School       98.4
# 90    1429  2022                 Valor Flagship Academy       98.3
# 27    1009  2020      East Nashville Magnet High School       98.3
# 70     939  2022                    MNPS Virtual School       97.9
# 116   1567  2023                  STEM Prep High School       97.6
# 50     971  2021      East Nashville Magnet High School       97.5
# 73    1011  2022      East Nashville Magnet High School       97.3
# 88    1394  2022  KIPP Nashville Collegiate High School       96.9
# 104   1311  2023           Nashville School Of The Arts       96.8

# %%
ax = sns.barplot(top10, x="school_name", y="grad_rate", estimator="sum", errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10)

# Set the title
ax.set_title("Highest Graduation Rates 2019-2023", fontsize=16)  # Adjust the title size as needed

# Set the x and y labels
ax.set_xlabel("School Name", fontsize=8)  # Change label size here
ax.set_ylabel("Graduation Rate", fontsize=8)  # Change label size here

# Optionally, adjust the tick parameters
ax.tick_params(axis='x', labelsize=4)  # Change x-tick label size
ax.tick_params(axis='y', labelsize=8)  # Change y-tick label size
ax.set_xticklabels(ax.get_xticklabels(), rotation=10)

# Show the plot
plt.show()

# %%
ax = sns.barplot(top10, x="school_name", y="grad_rate", estimator="sum", errorbar=None)

# Add bar labels
ax.bar_label(ax.containers[0], fontsize=8, label_type='edge')  # Adjust positioning with label_type

# Set the title
ax.set_title("Highest Graduation Rates 2019-2023", fontsize=16)

# Set the x and y labels
ax.set_xlabel("School Name", fontsize=8)
ax.set_ylabel("Graduation Rate", fontsize=8)

# Optionally, adjust the tick parameters
ax.tick_params(axis='x', labelsize=6)  # Change x-tick label size
ax.tick_params(axis='y', labelsize=8)

# Rotate x-tick labels to improve readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate more and align right

# Adjust layout to prevent clipping
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.plot('year', 'grad_rate', data=rates, linestyle='-', marker='o')
plt.show()

# %%
bottom = rates.sort_values('grad_rate', ascending=False).tail(10)
bottom
# Out:
#      index  year                  school_name  grad_rate
# 59    1254  2021  The Academy at Old Cockrill       68.4
# 15    1299  2019  The Academy at Old Cockrill       66.9
# 13    1263  2019              Pearl-Cohn High       64.0
# 28    1027  2020        Glencliff High School       62.8
# 51     989  2021        Glencliff High School       61.2
# 97    1083  2023        Glencliff High School       60.7
# 102   1254  2023               Maplewood High       58.8
# 74    1028  2022        Glencliff High School       53.1
# 32    1177  2020             Cora Howe School       42.9
# 9     1172  2019             Cora Howe School       20.0

# %%
mnps_rates['grad_rate'] = mnps_rates['grad_rate'].sort_values()

# %%
bottom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 59 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        10 non-null     int64
#  1   year         10 non-null     int64
#  2   school_name  10 non-null     object
#  3   grad_rate    10 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 400.0+ bytes

# %%
ax = sns.barplot(bottom, x="school_name", y="grad_rate", estimator="sum", errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10)

# Set the title
ax.set_title("Lowest Graduation Rates 2019-2023", fontsize=16)  # Adjust the title size as needed

# Set the x and y labels
ax.set_xlabel("School Name", fontsize=8)  # Change label size here
ax.set_ylabel("Graduation Rate", fontsize=8)  # Change label size here

# Optionally, adjust the tick parameters
ax.tick_params(axis='x', labelsize=8)  # Change x-tick label size
ax.tick_params(axis='y', labelsize=8)  # Change y-tick label size
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Show the plot
plt.show()

# %%
plt.plot('school_name', 'grad_rate', data=bottom, linestyle='-', marker='o')
plt.xlabel('School Name') # x-axis name
plt.ylabel('Graduation Rate') # y-axis name
plt.title('Metro Nashville Public School Graduation Rate') # Add a title
plt.show()

# %%
mnps_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 10 non-null     int64
#  1   year               10 non-null     int64
#  2   number_of_schools  10 non-null     int64
#  3   admin              10 non-null     int64
#  4   teachers           10 non-null     int64
#  5   total students     10 non-null     int64
#  6   k_8_attendance     10 non-null     float64
#  7   9_12_attendance    10 non-null     float64
#  8   library_budget     10 non-null     float64
#  9   social_budget      10 non-null     float64
#  10  mnps_budget        10 non-null     int64
#  11  comp_act           10 non-null     float64
#  12  grad_rate          10 non-null     float64
# dtypes: float64(6), int64(7)
# memory usage: 1.1 KB

# %%
mnps_rates.plot.barh( x='year', y='grad_rate', title='Metro Nashville Public Schools Graduation Rates Over the Years')
# Out:
# <Axes: title={'center': 'Metro Nashville Public Schools Graduation Rates Over the Years'}, ylabel='year'>

# %%
sns.scatterplot(x=mnps_rates["year"], y=mnps_rates["grad_rate"])
# Out:
# <Axes: xlabel='year', ylabel='grad_rate'>

# %%
plt.plot('year', 'grad_rate', data=mnps_rates, linestyle='-', marker='o')
plt.xlabel('Year') # x-axis name
plt.ylabel('Graduation Rate') # y-axis name
plt.title('Metro Nashville Public School Graduation Rate') # Add a title
plt.axhline(y=87, color='r', linestyle='-')
plt.show()

# %%
mnps_rates.describe()
# Out:
#              ID        year  number_of_schools       admin    teachers  \
# count  10.00000    10.00000            10.0000   10.000000    10.00000
# mean    4.50000  2014.50000           152.7000  592.600000  5304.00000
# std     3.02765     3.02765            11.0358  163.941182   309.28412
# min     0.00000  2010.00000           133.0000  334.000000  5050.00000
# 25%     2.25000  2012.25000           145.7500  558.250000  5093.25000
# 50%     4.50000  2014.50000           157.0000  596.500000  5193.50000
# 75%     6.75000  2016.75000           159.7500  696.000000  5374.00000
# max     9.00000  2019.00000           164.0000  849.000000  6046.00000
#
#        total students  k_8_attendance  9_12_attendance  library_budget  \
# count       10.000000       10.000000         10.00000    1.000000e+01
# mean     81749.500000       76.230000         73.38000    2.447848e+07
# std       3073.531926       40.177248         38.67643    4.911949e+06
# ...

# %%
plt.plot('year', 'mnps_budget', data=mnps_rates, linestyle='-', marker='o')
plt.xlabel('Year') # x-axis name
plt.ylabel('School Budget') # y-axis name
plt.title('Metro Nashville Public School Budget Per Year') # Add a title
plt.show()

# %%
sns.scatterplot(x=mnps_rates["mnps_budget"], y=mnps_rates["grad_rate"])
plt.xlabel('Budget') # x-axis name
plt.ylabel('Graduation Rate') # y-axis name
plt.title('Metro Nashville Public School Graduation Rate Vs. Budget') # Add a title
# Fit the trend line
z = np.polyfit(mnps_rates['mnps_budget'], mnps_rates['grad_rate'], 1)
p = np.poly1d(z)
plt.plot(mnps_rates['mnps_budget'],p(mnps_rates['mnps_budget']))
plt.show()

# %% [markdown]
# z = np.polyfit(mnps_rates['mnps_budget'], mnps_rates['grad_rate'], 1)
# p = np.poly1d(z)
# plt.plot(mnps_rates['mnps_budget'],p(mnps_rates['grad_rate']),"r--")

# %%
correlation = mnps_rates['grad_rate'].corr(mnps_rates['mnps_budget'])
correlation
# Out:
# 0.8764014222187502

# %% [markdown]
# mnps_rates.set_index(['year','mnps_budget','grad_rate']).plot.bar(rot=45)

# %%
plt.plot('mnps_budget', 'grad_rate', data=mnps_rates, linestyle='-', marker='o')
plt.xlabel('Budget') # x-axis name
plt.ylabel('Graduation Rate') # y-axis name
plt.title('Metro Nashville Public School Graduation Rate vs School Budget') # Add a title
plt.show()

# %%
plt.plot('mnps_budget', 'grad_rate', data=mnps_rates)
plt.xlabel('Budget') # x-axis name
plt.ylabel('Graduation Rate') # y-axis name
plt.title('Metro Nashville Public School Graduation Rate vs School Budget') # Add a title
plt.show()

# %%
ax = sns.barplot(mnps_rates, x="mnps_budget", y="grad_rate", estimator="sum", errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10)

# Set the title
ax.set_title("Graduation Rate vs. Budget", fontsize=16)  # Adjust the title size as needed

# Set the x and y labels
ax.set_xlabel("School Budget", fontsize=8)  # Change label size here
ax.set_ylabel("Graduation Rate", fontsize=8)  # Change label size here

# Optionally, adjust the tick parameters
ax.tick_params(axis='x', labelsize=8)  # Change x-tick label size
ax.tick_params(axis='y', labelsize=8)  # Change y-tick label size
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Show the plot
plt.show()

# %%
mnps_rates.plot.barh( x='grad_rate', y='mnps_budget', title='Metro Nashville Public Schools Graduation Rates Over the Years')
# Out:
# <Axes: title={'center': 'Metro Nashville Public Schools Graduation Rates Over the Years'}, ylabel='grad_rate'>
