# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grad_rate_19_20 = pd.read_csv(r'C:\DA12\capstone\capstone-da12\data\graduation rates\2019-20_school_grad_rate_suppressed.csv')
grad_rate_19_20
# Out:
#       year  system                         system_name  school  \
# 0     2020      10                     Anderson County       2
# 1     2020      10                     Anderson County       2
# 2     2020      10                     Anderson County       2
# 3     2020      10                     Anderson County       2
# 4     2020      10                     Anderson County       2
# ...    ...     ...                                 ...     ...
# 7322  2020     986  Tennessee State Board of Education    8005
# 7323  2020     986  Tennessee State Board of Education    8005
# 7324  2020     986  Tennessee State Board of Education    8005
# 7325  2020     986  Tennessee State Board of Education    8005
# 7326  2020     986  Tennessee State Board of Education    8005
#
#                       school_name                               subgroup  \
# 0     Anderson County High School                           All Students
# 1     Anderson County High School                                  Asian
# 2     Anderson County High School              Black or African American
# 3     Anderson County High School         Black/Hispanic/Native American
# 4     Anderson County High School             Economically Disadvantaged
# ...                           ...                                    ...
# 7322       Bluff City High School  Non-English Learners/Transitional 1-4
# 7323       Bluff City High School                           Non-Homeless
# 7324       Bluff City High School                            Non-Migrant
# 7325       Bluff City High School         Non-Students with Disabilities
# 7326       Bluff City High School             Students with Disabilities
#
#       grad_cohort grad_count grad_rate
# 0             250        243      97.2
# 1               1          *         *
# 2               3          *         *
# 3               9          *         *
# 4              79         74      93.7
# ...           ...        ...       ...
# 7322            3          *         *
# 7323            2          *         *
# 7324            3          *         *
# 7325            2          *         *
# 7326            1          *         *
#
# [7327 rows x 9 columns]

# %%
grad_rate_20 = grad_rate_19_20[grad_rate_19_20['system_name']=='Davidson County']
grad_rate_20
# Out:
#       year  system      system_name  school           school_name  \
# 928   2020     190  Davidson County       3   MNPS Virtual School
# 929   2020     190  Davidson County       3   MNPS Virtual School
# 930   2020     190  Davidson County       3   MNPS Virtual School
# 931   2020     190  Davidson County       3   MNPS Virtual School
# 932   2020     190  Davidson County       3   MNPS Virtual School
# ...    ...     ...              ...     ...                   ...
# 1499  2020     190  Davidson County    8100  RePublic High School
# 1500  2020     190  Davidson County    8100  RePublic High School
# 1501  2020     190  Davidson County    8100  RePublic High School
# 1502  2020     190  Davidson County    8100  RePublic High School
# 1503  2020     190  Davidson County    8100  RePublic High School
#
#                             subgroup  grad_cohort grad_count grad_rate
# 928                     All Students           20         17        85
# 929                            Asian            1          *         *
# 930        Black or African American            1          *         *
# 931   Black/Hispanic/Native American            1          *         *
# 932       Economically Disadvantaged            4          *         *
# ...                              ...          ...        ...       ...
# 1499                    Non-Homeless          108         97      89.8
# 1500                     Non-Migrant          110         99        90
# 1501  Non-Students with Disabilities           97         90      92.8
# 1502      Students with Disabilities           14         10      71.4
# 1503                           White            9          *         *
#
# [576 rows x 9 columns]

# %%
grad_rate_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 576 entries, 928 to 1503
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         576 non-null    int64
#  1   system       576 non-null    int64
#  2   system_name  576 non-null    object
#  3   school       576 non-null    int64
#  4   school_name  576 non-null    object
#  5   subgroup     576 non-null    object
#  6   grad_cohort  576 non-null    int64
#  7   grad_count   576 non-null    object
#  8   grad_rate    576 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 45.0+ KB

# %%
grad_rate_20['grad_rate'].max()
# Out:
# '98.8'

# %%
grad_rate_20['school_name'].loc[grad_rate_20['grad_rate'].idxmax()]
# Out:
# 'East Nashville Magnet High School'

# %%
grad_rate_20[grad_rate_20['subgroup']=="All Students"].groupby('subgroup').grad_rate.max()
# Out:
# subgroup
# All Students    98.3
# Name: grad_rate, dtype: object

# %%
rates = grad_rate_20[grad_rate_20['subgroup']=='All Students']
rates
# Out:
#       year  system      system_name  school  \
# 928   2020     190  Davidson County       3
# 944   2020     190  Davidson County      20
# 963   2020     190  Davidson County      53
# 981   2020     190  Davidson County      77
# 1000  2020     190  Davidson County     165
# 1009  2020     190  Davidson County     203
# 1027  2020     190  Davidson County     245
# 1046  2020     190  Davidson County     302
# 1063  2020     190  Davidson County     335
# 1082  2020     190  Davidson County     340
# 1102  2020     190  Davidson County     355
# 1119  2020     190  Davidson County     358
# 1138  2020     190  Davidson County     395
# 1159  2020     190  Davidson County     437
# 1177  2020     190  Davidson County     443
# 1194  2020     190  Davidson County     445
# 1212  2020     190  Davidson County     456
# 1230  2020     190  Davidson County     470
# 1250  2020     190  Davidson County     512
# 1268  2020     190  Davidson County     555
# 1285  2020     190  Davidson County     612
# 1303  2020     190  Davidson County     614
# 1322  2020     190  Davidson County     620
# 1341  2020     190  Davidson County     704
# 1358  2020     190  Davidson County     720
# 1376  2020     190  Davidson County     725
# 1391  2020     190  Davidson County     745
# 1408  2020     190  Davidson County    8003
# 1426  2020     190  Davidson County    8011
# 1443  2020     190  Davidson County    8013
# 1452  2020     190  Davidson County    8065
# 1470  2020     190  Davidson County    8075
# 1486  2020     190  Davidson County    8100
#
#                                 school_name      subgroup  grad_cohort  \
# 928                     MNPS Virtual School  All Students           20
# 944                     Antioch High School  All Students          518
# 963       Nashville Big Picture High School  All Students           24
# 981                  Cane Ridge High School  All Students          474
# 1000                      Dodson Elementary  All Students            0
# 1009      East Nashville Magnet High School  All Students          180
# 1027                  Glencliff High School  All Students          339
# 1046       Harris-Hillman Special Education  All Students           10
# 1063                         Hillsboro High  All Students          260
# 1082                          Hillwood High  All Students          258
# 1102                       Hume - Fogg High  All Students          221
# 1119                      Hunters Lane High  All Students          367
# 1138                      John Overton High  All Students          552
# 1159                    Middle College High  All Students           47
# 1177                       Cora Howe School  All Students           14
# 1194                         Maplewood High  All Students          234
# 1212           Martin Luther King Jr School  All Students          231
# 1230                          McGavock High  All Students          538
# 1250           Nashville School Of The Arts  All Students          139
# 1268                        Pearl-Cohn High  All Students          171
# 1285              The Academy at Opry Mills  All Students           65
# 1303            The Academy at Old Cockrill  All Students          131
# 1322           Stratford STEM Magnet School  All Students          169
# 1341                      Whites Creek High  All Students          148
# 1358          The Academy at Hickory Hollow  All Students          156
# 1376                    Transitions at Bass  All Students            8
# 1391               The Cohn Learning Center  All Students           40
# 1408                           Lead Academy  All Students           75
# 1426  KIPP Nashville Collegiate High School  All Students           67
# 1443                         LEAD Southeast  All Students            1
# 1452        Knowledge Academies High School  All Students           37
# 1470                  STEM Prep High School  All Students           99
# 1486                   RePublic High School  All Students          111
#
#      grad_count grad_rate
# 928          17        85
# 944         420      81.1
# 963          **        **
# 981         396      83.5
# 1000          *         *
# 1009        177      98.3
# 1027        213      62.8
# 1046         **        **
# 1063        233      89.6
# 1082        221      85.7
# 1102         **        **
# 1119        294      80.1
# 1138        442      80.1
# 1159         **        **
# 1177          6      42.9
# 1194        162      69.2
# 1212         **        **
# 1230        428      79.6
# 1250        131      94.2
# 1268        130        76
# 1285         57      87.7
# 1303         99      75.6
# 1322        136      80.5
# 1341        115      77.7
# 1358        137      87.8
# 1376          *         *
# 1391         **        **
# 1408         70      93.3
# 1426         57      85.1
# 1443          *         *
# 1452         34      91.9
# 1470         95        96
# 1486        100      90.1

# %%
rates = rates[['school_name', 'grad_rate']]
rates
# Out:
#                                 school_name grad_rate
# 928                     MNPS Virtual School        85
# 944                     Antioch High School      81.1
# 963       Nashville Big Picture High School        **
# 981                  Cane Ridge High School      83.5
# 1000                      Dodson Elementary         *
# 1009      East Nashville Magnet High School      98.3
# 1027                  Glencliff High School      62.8
# 1046       Harris-Hillman Special Education        **
# 1063                         Hillsboro High      89.6
# 1082                          Hillwood High      85.7
# 1102                       Hume - Fogg High        **
# 1119                      Hunters Lane High      80.1
# 1138                      John Overton High      80.1
# 1159                    Middle College High        **
# 1177                       Cora Howe School      42.9
# 1194                         Maplewood High      69.2
# 1212           Martin Luther King Jr School        **
# 1230                          McGavock High      79.6
# 1250           Nashville School Of The Arts      94.2
# 1268                        Pearl-Cohn High        76
# 1285              The Academy at Opry Mills      87.7
# 1303            The Academy at Old Cockrill      75.6
# 1322           Stratford STEM Magnet School      80.5
# 1341                      Whites Creek High      77.7
# 1358          The Academy at Hickory Hollow      87.8
# 1376                    Transitions at Bass         *
# 1391               The Cohn Learning Center        **
# 1408                           Lead Academy      93.3
# 1426  KIPP Nashville Collegiate High School      85.1
# 1443                         LEAD Southeast         *
# 1452        Knowledge Academies High School      91.9
# 1470                  STEM Prep High School        96
# 1486                   RePublic High School      90.1

# %%
rates['grad_rate'].max()
# Out:
# '98.3'

# %%
rates.loc[rates['grad_rate']==98.3]
# Out:
# Empty DataFrame
# Columns: [school_name, grad_rate]
# Index: []

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 928 to 1486
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school_name  33 non-null     object
#  1   grad_rate    33 non-null     object
# dtypes: object(2)
# memory usage: 792.0+ bytes

# %%
rates.sort_values('grad_rate')
# Out:
#                                 school_name grad_rate
# 1376                    Transitions at Bass         *
# 1000                      Dodson Elementary         *
# 1443                         LEAD Southeast         *
# 1212           Martin Luther King Jr School        **
# 1159                    Middle College High        **
# 1391               The Cohn Learning Center        **
# 1046       Harris-Hillman Special Education        **
# 1102                       Hume - Fogg High        **
# 963       Nashville Big Picture High School        **
# 1177                       Cora Howe School      42.9
# 1027                  Glencliff High School      62.8
# 1194                         Maplewood High      69.2
# 1303            The Academy at Old Cockrill      75.6
# 1268                        Pearl-Cohn High        76
# 1341                      Whites Creek High      77.7
# 1230                          McGavock High      79.6
# 1119                      Hunters Lane High      80.1
# 1138                      John Overton High      80.1
# 1322           Stratford STEM Magnet School      80.5
# 944                     Antioch High School      81.1
# 981                  Cane Ridge High School      83.5
# 928                     MNPS Virtual School        85
# 1426  KIPP Nashville Collegiate High School      85.1
# 1082                          Hillwood High      85.7
# 1285              The Academy at Opry Mills      87.7
# 1358          The Academy at Hickory Hollow      87.8
# 1063                         Hillsboro High      89.6
# 1486                   RePublic High School      90.1
# 1452        Knowledge Academies High School      91.9
# 1408                           Lead Academy      93.3
# 1250           Nashville School Of The Arts      94.2
# 1470                  STEM Prep High School        96
# 1009      East Nashville Magnet High School      98.3

# %%
rates = rates.drop(rates[rates['grad_rate'] == '*'].index)
rates
# Out:
#                                 school_name grad_rate
# 928                     MNPS Virtual School        85
# 944                     Antioch High School      81.1
# 963       Nashville Big Picture High School        **
# 981                  Cane Ridge High School      83.5
# 1009      East Nashville Magnet High School      98.3
# 1027                  Glencliff High School      62.8
# 1046       Harris-Hillman Special Education        **
# 1063                         Hillsboro High      89.6
# 1082                          Hillwood High      85.7
# 1102                       Hume - Fogg High        **
# 1119                      Hunters Lane High      80.1
# 1138                      John Overton High      80.1
# 1159                    Middle College High        **
# 1177                       Cora Howe School      42.9
# 1194                         Maplewood High      69.2
# 1212           Martin Luther King Jr School        **
# 1230                          McGavock High      79.6
# 1250           Nashville School Of The Arts      94.2
# 1268                        Pearl-Cohn High        76
# 1285              The Academy at Opry Mills      87.7
# 1303            The Academy at Old Cockrill      75.6
# 1322           Stratford STEM Magnet School      80.5
# 1341                      Whites Creek High      77.7
# 1358          The Academy at Hickory Hollow      87.8
# 1391               The Cohn Learning Center        **
# 1408                           Lead Academy      93.3
# 1426  KIPP Nashville Collegiate High School      85.1
# 1452        Knowledge Academies High School      91.9
# 1470                  STEM Prep High School        96
# 1486                   RePublic High School      90.1

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 928 to 1486
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school_name  30 non-null     object
#  1   grad_rate    30 non-null     object
# dtypes: object(2)
# memory usage: 720.0+ bytes

# %%
rates = rates.drop(rates[rates['grad_rate'] == '**'].index)
rates
# Out:
#                                 school_name grad_rate
# 928                     MNPS Virtual School        85
# 944                     Antioch High School      81.1
# 981                  Cane Ridge High School      83.5
# 1009      East Nashville Magnet High School      98.3
# 1027                  Glencliff High School      62.8
# 1063                         Hillsboro High      89.6
# 1082                          Hillwood High      85.7
# 1119                      Hunters Lane High      80.1
# 1138                      John Overton High      80.1
# 1177                       Cora Howe School      42.9
# 1194                         Maplewood High      69.2
# 1230                          McGavock High      79.6
# 1250           Nashville School Of The Arts      94.2
# 1268                        Pearl-Cohn High        76
# 1285              The Academy at Opry Mills      87.7
# 1303            The Academy at Old Cockrill      75.6
# 1322           Stratford STEM Magnet School      80.5
# 1341                      Whites Creek High      77.7
# 1358          The Academy at Hickory Hollow      87.8
# 1408                           Lead Academy      93.3
# 1426  KIPP Nashville Collegiate High School      85.1
# 1452        Knowledge Academies High School      91.9
# 1470                  STEM Prep High School        96
# 1486                   RePublic High School      90.1

# %%
rates.columns = rates.columns.str.replace(' ', '')
rates
# Out:
#                                 school_name grad_rate
# 928                     MNPS Virtual School        85
# 944                     Antioch High School      81.1
# 981                  Cane Ridge High School      83.5
# 1009      East Nashville Magnet High School      98.3
# 1027                  Glencliff High School      62.8
# 1063                         Hillsboro High      89.6
# 1082                          Hillwood High      85.7
# 1119                      Hunters Lane High      80.1
# 1138                      John Overton High      80.1
# 1177                       Cora Howe School      42.9
# 1194                         Maplewood High      69.2
# 1230                          McGavock High      79.6
# 1250           Nashville School Of The Arts      94.2
# 1268                        Pearl-Cohn High        76
# 1285              The Academy at Opry Mills      87.7
# 1303            The Academy at Old Cockrill      75.6
# 1322           Stratford STEM Magnet School      80.5
# 1341                      Whites Creek High      77.7
# 1358          The Academy at Hickory Hollow      87.8
# 1408                           Lead Academy      93.3
# 1426  KIPP Nashville Collegiate High School      85.1
# 1452        Knowledge Academies High School      91.9
# 1470                  STEM Prep High School        96
# 1486                   RePublic High School      90.1

# %% [markdown]
# rates['grad_rate'].nlargest(n=5)

# %% [markdown]
# df['column'].nlargest(n=5)

# %%
rates['grad_rate'] =rates['grad_rate'].astype(float)
rates
# Out:
#                                 school_name  grad_rate
# 928                     MNPS Virtual School       85.0
# 944                     Antioch High School       81.1
# 981                  Cane Ridge High School       83.5
# 1009      East Nashville Magnet High School       98.3
# 1027                  Glencliff High School       62.8
# 1063                         Hillsboro High       89.6
# 1082                          Hillwood High       85.7
# 1119                      Hunters Lane High       80.1
# 1138                      John Overton High       80.1
# 1177                       Cora Howe School       42.9
# 1194                         Maplewood High       69.2
# 1230                          McGavock High       79.6
# 1250           Nashville School Of The Arts       94.2
# 1268                        Pearl-Cohn High       76.0
# 1285              The Academy at Opry Mills       87.7
# 1303            The Academy at Old Cockrill       75.6
# 1322           Stratford STEM Magnet School       80.5
# 1341                      Whites Creek High       77.7
# 1358          The Academy at Hickory Hollow       87.8
# 1408                           Lead Academy       93.3
# 1426  KIPP Nashville Collegiate High School       85.1
# 1452        Knowledge Academies High School       91.9
# 1470                  STEM Prep High School       96.0
# 1486                   RePublic High School       90.1

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 928 to 1486
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school_name  24 non-null     object
#  1   grad_rate    24 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 576.0+ bytes

# %%
top5 = rates.sort_values('grad_rate', ascending=False).head(5)
top5
# Out:
#                             school_name  grad_rate
# 1009  East Nashville Magnet High School       98.3
# 1470              STEM Prep High School       96.0
# 1250       Nashville School Of The Arts       94.2
# 1408                       Lead Academy       93.3
# 1452    Knowledge Academies High School       91.9

# %%
top5.plot.barh( x='school_name', y='grad_rate')
# Out:
# <Axes: ylabel='school_name'>

# %%
bottom = rates.sort_values('grad_rate', ascending=False).tail(5)
bottom
# Out:
#                       school_name  grad_rate
# 1268              Pearl-Cohn High       76.0
# 1303  The Academy at Old Cockrill       75.6
# 1194               Maplewood High       69.2
# 1027        Glencliff High School       62.8
# 1177             Cora Howe School       42.9

# %%
sns.set_theme(style="white", context="talk")
rs = np.random.RandomState(8)

# %%
ax = sns.barplot(bottom, x="school_name", y="grad_rate", estimator="sum", errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10)

# Set the title
ax.set_title("Graduation Rates by School 2020", fontsize=16)  # Adjust the title size as needed

# Set the x and y labels
ax.set_xlabel("School Name", fontsize=8)  # Change label size here
ax.set_ylabel("Graduation Rate", fontsize=8)  # Change label size here

# Optionally, adjust the tick parameters
ax.tick_params(axis='x', labelsize=8)  # Change x-tick label size
ax.tick_params(axis='y', labelsize=8)  # Change y-tick label size
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Show the plot
plt.show()
